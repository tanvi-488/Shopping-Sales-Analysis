# %% [markdown]
# <a href="https://colab.research.google.com/github/tanvi-488/Shopping-Sales-Analysis/blob/main/Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/customer_shopping_data.csv')

# %%
df.head()
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 3    I173702     C988172  Female   66     Shoes         5  3000.85
# 4    I337046     C189076  Female   53     Books         4    60.60
#
#   payment_method invoice_date   shopping_mall
# 0    Credit Card     5/8/2022          Kanyon
# 1     Debit Card   12/12/2021  Forum Istanbul
# 2           Cash    9/11/2021       Metrocity
# 3    Credit Card   16/05/2021    Metropol AVM
# 4           Cash   24/10/2021          Kanyon

# %%
df.describe()
# Out:
#                 age      quantity         price
# count  82958.000000  82958.000000  82957.000000
# mean      43.420755      3.002941    690.084645
# std       14.992913      1.413307    943.041157
# min       18.000000      1.000000      5.230000
# 25%       30.000000      2.000000     45.450000
# 50%       43.000000      3.000000    203.300000
# 75%       56.000000      4.000000   1200.320000
# max       69.000000      5.000000   5250.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82958 entries, 0 to 82957
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_no      82958 non-null  object
#  1   customer_id     82958 non-null  object
#  2   gender          82958 non-null  object
#  3   age             82958 non-null  int64
#  4   category        82958 non-null  object
#  5   quantity        82958 non-null  int64
#  6   price           82957 non-null  float64
#  7   payment_method  82957 non-null  object
#  8   invoice_date    82957 non-null  object
#  9   shopping_mall   82957 non-null  object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 6.3+ MB

# %%
new_df=df.dropna()

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 82957 entries, 0 to 82956
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_no      82957 non-null  object
#  1   customer_id     82957 non-null  object
#  2   gender          82957 non-null  object
#  3   age             82957 non-null  int64
#  4   category        82957 non-null  object
#  5   quantity        82957 non-null  int64
#  6   price           82957 non-null  float64
#  7   payment_method  82957 non-null  object
#  8   invoice_date    82957 non-null  object
#  9   shopping_mall   82957 non-null  object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 7.0+ MB

# %%
new_df.loc[:, 'invoice_date'] = pd.to_datetime(new_df['invoice_date'], format='%d%m%y')
# Out:
# <ipython-input-14-ebfda9efe4ce>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.loc[:, 'invoice_date'] = pd.to_datetime(new_df['invoice_date'], format='%d%m%y')
# <ipython-input-14-ebfda9efe4ce>:1: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   new_df.loc[:, 'invoice_date'] = pd.to_datetime(new_df['invoice_date'], format='%d%m%y')

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 82957 entries, 0 to 82956
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_no      82957 non-null  object
#  1   customer_id     82957 non-null  object
#  2   gender          82957 non-null  object
#  3   age             82957 non-null  int64
#  4   category        82957 non-null  object
#  5   quantity        82957 non-null  int64
#  6   price           82957 non-null  float64
#  7   payment_method  82957 non-null  object
#  8   invoice_date    82957 non-null  datetime64[ns]
#  9   shopping_mall   82957 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(6)
# memory usage: 7.0+ MB

# %%
new_df.head()
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 3    I173702     C988172  Female   66     Shoes         5  3000.85
# 4    I337046     C189076  Female   53     Books         4    60.60
#
#   payment_method invoice_date   shopping_mall
# 0    Credit Card   2022-05-08          Kanyon
# 1     Debit Card   2021-12-12  Forum Istanbul
# 2           Cash   2021-09-11       Metrocity
# 3    Credit Card   2021-05-16    Metropol AVM
# 4           Cash   2021-10-24          Kanyon

# %%
new_df.to_csv('Cleaned_shopping_data.csv')
